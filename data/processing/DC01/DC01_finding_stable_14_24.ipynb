# %%
import pandas as pd

# %%
df_tech_sp500=pd.read_csv("../../processed/tech_sp500_stable_extended_tickers.csv")

# %%
df_tech_sp500
# Out:
#          cik                           name entityType     sic  \
# 0     320193                     Apple Inc.  operating  3571.0
# 1     789019                 MICROSOFT CORP  operating  7372.0
# 2    1045810                    NVIDIA CORP  operating  3674.0
# 3    1652044                  Alphabet Inc.  operating  7370.0
# 4    1326801           Meta Platforms, Inc.  operating  7370.0
# ..       ...                            ...        ...     ...
# 119    78814          PITNEY BOWES INC /DE/  operating  3579.0
# 120  1770450            Xerox Holdings Corp  operating  3577.0
# 121    61986               MANITOWOC CO INC  operating  3531.0
# 122  1881551       Solidion Technology Inc.  operating  3690.0
# 123  1621672  Super League Enterprise, Inc.  operating  7373.0
#
#                                         sicDescription          ownerOrg  \
# 0                                 Electronic Computers     06 Technology
# 1                        Services-Prepackaged Software     06 Technology
# 2                     Semiconductors & Related Devices  04 Manufacturing
# 3    Services-Computer Programming, Data Processing...     06 Technology
# 4    Services-Computer Programming, Data Processing...     06 Technology
# ..                                                 ...               ...
# 119                               Office Machines, NEC     06 Technology
# 120                 Computer Peripheral Equipment, NEC     06 Technology
# 121                     Construction Machinery & Equip     06 Technology
# 122  Miscellaneous Electrical Machinery, Equipment ...  04 Manufacturing
# 123        Services-Computer Integrated Systems Design     06 Technology
#
#      insiderTransactionForOwnerExists  insiderTransactionForIssuerExists  \
# 0                                   0                                  1
# 1                                   1                                  1
# 2                                   1                                  1
# 3                                   1                                  1
# 4                                   0                                  1
# ..                                ...                                ...
# 119                                 0                                  1
# 120                                 0                                  1
# 121                                 1                                  1
# 122                                 0                                  1
# 123                                 0                                  1
#
#         tickers      exchanges  ...  mailing_stateOrCountryDescription  \
# 0          AAPL         Nasdaq  ...                                 CA
# 1          MSFT         Nasdaq  ...                                 WA
# 2          NVDA         Nasdaq  ...                                 CA
# 3    GOOGL,GOOG  Nasdaq,Nasdaq  ...                                 CA
# 4       META,FB         Nasdaq  ...                                 CA
# ..          ...            ...  ...                                ...
# 119  PBI,PBI-PB      NYSE,NYSE  ...                                 CT
# 120         XRX         Nasdaq  ...                                 CT
# 121         MTW           NYSE  ...                                 WI
# 122         STI         Nasdaq  ...                                 TX
# 123         SLE         Nasdaq  ...                                 CA
#
#                business_street1    business_street2  business_city  \
# 0            ONE APPLE PARK WAY                 NaN      CUPERTINO
# 1             ONE MICROSOFT WAY                 NaN        REDMOND
# 2     2788 SAN TOMAS EXPRESSWAY                 NaN    SANTA CLARA
# 3     1600 AMPHITHEATRE PARKWAY                 NaN  MOUNTAIN VIEW
# 4                    1 META WAY                 NaN     MENLO PARK
# ..                          ...                 ...            ...
# 119            PITNEY BOWES INC  3001 SUMMER STREET       STAMFORD
# 120               201 MERRITT 7                 NaN        NORWALK
# 121       11270 WEST PARK PLACE         SUITE 10000      MILWAUKEE
# 122             13355 NOEL ROAD          SUITE 1100         DALLAS
# 123  2912 COLORADO AVE, STE 203                 NaN   SANTA MONICA
#
#     business_stateOrCountry  business_zipCode  \
# 0                        CA             95014
# 1                        WA        98052-6399
# 2                        CA             95051
# 3                        CA             94043
# 4                        CA             94025
# ..                      ...               ...
# 119                      CT        06926-0700
# 120                      CT             06851
# 121                      WI             53224
# 122                      TX             75240
# 123                      CA             90404
#
#     business_stateOrCountryDescription                               naics  \
# 0                                   CA                              334111
# 1                                   WA                       511210,334614
# 2                                   CA                              334413
# 3                                   CA                       518210,541511
# 4                                   CA                       518210,541511
# ..                                 ...                                 ...
# 119                                 CT                339940,333318,334519
# 120                                 CT         334418,333316,334613,334118
# 121                                 WI                333120,333923,336510
# 122                                 TX  333618,333318,333992,335129,335999
# 123                                 CA                              541512
#
#     stable 12 to 24  extended tickers
# 0              True        AAPL*,AAPL
# 1              True              MSFT
# 2              True              NVDA
# 3              True  GOOG,GOOGL,GOOG*
# 4             False       FB*,FB,META
# ..              ...               ...
# 119           False        PBI,PBI-PB
# 120           False               XRX
# 121           False               MTW
# 122           False               STI
# 123           False               SLE
#
# [124 rows x 35 columns]

# %%
df_his_weight=pd.read_csv("../../processed/his_weight_tech_500_12_24_in_progress.csv")

# %%
df_his_weight
# Out:
#               date   rank ticker                                name  \
# 0       2012-04-30    1.0  AAPL*                           APPLE INC
# 1       2012-04-30    3.0    IBM  INTERNATIONAL BUSINESS MACHINES CO
# 2       2012-04-30    4.0   MSFT                      MICROSOFT CORP
# 3       2012-04-30    7.0      T                            AT&T INC
# 4       2012-04-30   15.0  GOOGL                  GOOGLE INC CLASS A
# ...            ...    ...    ...                                 ...
# 237258  2024-10-30  485.0    HAS                          HASBRO INC
# 237259  2024-10-30  489.0   PAYC                 PAYCOM SOFTWARE INC
# 237260  2024-10-30  496.0   QRVO                           QORVO INC
# 237261  2024-10-30  500.0   PARA            PARAMOUNT GLOBAL CLASS B
# 237262  2024-10-30  501.0    FOX                    FOX CORP CLASS B
#
#                             sector    weight
# 0           Information Technology  4.306649
# 1           Information Technology  1.896926
# 2           Information Technology  1.890466
# 3       Telecommunication Services  1.542570
# 4           Information Technology  1.213489
# ...                            ...       ...
# 237258      Consumer Discretionary  0.017720
# 237259                 Industrials  0.017020
# 237260      Information Technology  0.014060
# 237261               Communication  0.012860
# 237262               Communication  0.010430
#
# [237263 rows x 6 columns]

# %%
df_his_weight_14_24=df_his_weight[df_his_weight.date>"2013-12-31"]

# %%
df_his_weight_14_24
# Out:
#               date   rank ticker                                name  \
# 26936   2014-01-02    1.0  AAPL*                           APPLE INC
# 26937   2014-01-02    3.0  GOOGL                  GOOGLE INC CLASS A
# 26938   2014-01-02    4.0   MSFT                      MICROSOFT CORP
# 26939   2014-01-02   13.0    IBM  INTERNATIONAL BUSINESS MACHINES CO
# 26940   2014-01-02   14.0      T                            AT&T INC
# ...            ...    ...    ...                                 ...
# 237258  2024-10-30  485.0    HAS                          HASBRO INC
# 237259  2024-10-30  489.0   PAYC                 PAYCOM SOFTWARE INC
# 237260  2024-10-30  496.0   QRVO                           QORVO INC
# 237261  2024-10-30  500.0   PARA            PARAMOUNT GLOBAL CLASS B
# 237262  2024-10-30  501.0    FOX                    FOX CORP CLASS B
#
#                             sector    weight
# 26936       Information Technology  3.038308
# 26937       Information Technology  1.906967
# 26938       Information Technology  1.723382
# 26939       Information Technology  1.156141
# 26940   Telecommunication Services  1.124044
# ...                            ...       ...
# 237258      Consumer Discretionary  0.017720
# 237259                 Industrials  0.017020
# 237260      Information Technology  0.014060
# 237261               Communication  0.012860
# 237262               Communication  0.010430
#
# [210327 rows x 6 columns]

# %%
len(df_his_weight_14_24.date.unique())
# Out:
# 2577

# %% [markdown]
# 2577 is the number of unique dates between 2014 and 2024 (when there is stock data).

# %%
lst_tics_tech_500_set=[set(str_ele.split(",")) for str_ele in list(df_tech_sp500["extended tickers"])]

# %%
lst_tics_tech_500_set
# Out:
# [{'AAPL', 'AAPL*'},
#  {'MSFT'},
#  {'NVDA'},
#  {'GOOG', 'GOOG*', 'GOOGL'},
#  {'FB', 'FB*', 'META'},
#  {'AVGO', 'BRCM'},
#  {'ORCL'},
#  {'CRM'},
#  {'ADBE'},
#  {'AMD'},
#  {'TMO'},
#  {'TMUS'},
#  {'CSCO'},
#  {'DHR'},
#  {'INTU'},
#  {'TXN'},
#  {'IBM'},
#  {'AMAT'},
#  {'NOW'},
#  {'VZ'},
#  {'CAT'},
#  {'CCZ', 'CMCSA'},
#  {'T', 'T-PA', 'T-PC', 'TBB', 'TBC'},
#  {'MU'},
#  {'ETN'},
#  {'LRCX'},
#  {'ANET'},
#  {'ADI'},
#  {'PANW'},
#  {'MDT'},
#  {'ADP'},
#  {'DE'},
#  {'INTC'},
#  {'SNPS'},
#  {'APH'},
#  {'DELL'},
#  {'CDNS'},
#  {'TT'},
#  {'PLTR'},
#  {'ITW'},
#  {'NXPI'},
#  {'CRWD'},
#  {'CARR'},
#  {'ROP'},
#  {'FTNT'},
#  {'ADSK'},
#  {'CHTR'},
#  {'JCI'},
#  {'MPWR'},
#  {'MCHP'},
#  {'CMI'},
#  {'EA'},
#  {'VRSK'},
#  {'AME'},
#  {'CTSH'},
#  {'IR'},
#  {'SMCI'},
#  {'HPQ'},
#  {'BKR'},
#  {'ON'},
#  {'XYL'},
#  {'ROK'},
#  {'ANSS'},
#  {'NTAP'},
#  {'VLTO'},
#  {'TTWO'},
#  {'TYL'},
#  {'DOV'},
#  {'HPE', 'HPE-PC'},
#  {'FTV'},
#  {'FSLR'},
#  {'KEYS'},
#  {'GDDY'},
#  {'TER'},
#  {'STX'},
#  {'WDC'},
#  {'PTC'},
#  {'HUBB'},
#  {'LDOS'},
#  {'WBD'},
#  {'ZBRA'},
#  {'FOX', 'FOXA'},
#  {'VRSN'},
#  {'SWKS'},
#  {'ENPH'},
#  {'FDS'},
#  {'GEN'},
#  {'IEX'},
#  {'PNR'},
#  {'NDSN'},
#  {'TRMB'},
#  {'JNPR'},
#  {'JKHY'},
#  {'FTI'},
#  {'EPAM'},
#  {'FFIV'},
#  {'ITT'},
#  {'QRVO'},
#  {'HAS'},
#  {'PAYC'},
#  {'MTCH'},
#  {'DAY'},
#  {'PARA', 'PARAA'},
#  {'CIEN'},
#  {'ALTR'},
#  {'AYI'},
#  {'S', 'S*'},
#  {'NOV'},
#  {'HCP'},
#  {'FLS'},
#  {'LUMN'},
#  {'DXC'},
#  {'DV'},
#  {'IPGP'},
#  {'TDC'},
#  {'TGNA'},
#  {'TRIP'},
#  {'SEDG'},
#  {'DNOW'},
#  {'PBI', 'PBI-PB'},
#  {'XRX'},
#  {'MTW'},
#  {'STI'},
#  {'SLE'}]

# %% [markdown]
# We leave some room again, we will deem a company is stable if there is less than 7 days of missing data.

# %%
lst_stable_14_24=[]

for ele_set in lst_tics_tech_500_set: 
    lst_stable_14_24.append(len(df_his_weight_14_24[df_his_weight_14_24.ticker.isin(ele_set)])>=2570)

# %%
lst_stable_14_24
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
len(lst_stable_14_24)
# Out:
# 124

# %%
df_tech_sp500["stable 14 to 24"]=lst_stable_14_24

# %%
df_tech_sp500
# Out:
#          cik                           name entityType     sic  \
# 0     320193                     Apple Inc.  operating  3571.0
# 1     789019                 MICROSOFT CORP  operating  7372.0
# 2    1045810                    NVIDIA CORP  operating  3674.0
# 3    1652044                  Alphabet Inc.  operating  7370.0
# 4    1326801           Meta Platforms, Inc.  operating  7370.0
# ..       ...                            ...        ...     ...
# 119    78814          PITNEY BOWES INC /DE/  operating  3579.0
# 120  1770450            Xerox Holdings Corp  operating  3577.0
# 121    61986               MANITOWOC CO INC  operating  3531.0
# 122  1881551       Solidion Technology Inc.  operating  3690.0
# 123  1621672  Super League Enterprise, Inc.  operating  7373.0
#
#                                         sicDescription          ownerOrg  \
# 0                                 Electronic Computers     06 Technology
# 1                        Services-Prepackaged Software     06 Technology
# 2                     Semiconductors & Related Devices  04 Manufacturing
# 3    Services-Computer Programming, Data Processing...     06 Technology
# 4    Services-Computer Programming, Data Processing...     06 Technology
# ..                                                 ...               ...
# 119                               Office Machines, NEC     06 Technology
# 120                 Computer Peripheral Equipment, NEC     06 Technology
# 121                     Construction Machinery & Equip     06 Technology
# 122  Miscellaneous Electrical Machinery, Equipment ...  04 Manufacturing
# 123        Services-Computer Integrated Systems Design     06 Technology
#
#      insiderTransactionForOwnerExists  insiderTransactionForIssuerExists  \
# 0                                   0                                  1
# 1                                   1                                  1
# 2                                   1                                  1
# 3                                   1                                  1
# 4                                   0                                  1
# ..                                ...                                ...
# 119                                 0                                  1
# 120                                 0                                  1
# 121                                 1                                  1
# 122                                 0                                  1
# 123                                 0                                  1
#
#         tickers      exchanges  ...            business_street1  \
# 0          AAPL         Nasdaq  ...          ONE APPLE PARK WAY
# 1          MSFT         Nasdaq  ...           ONE MICROSOFT WAY
# 2          NVDA         Nasdaq  ...   2788 SAN TOMAS EXPRESSWAY
# 3    GOOGL,GOOG  Nasdaq,Nasdaq  ...   1600 AMPHITHEATRE PARKWAY
# 4       META,FB         Nasdaq  ...                  1 META WAY
# ..          ...            ...  ...                         ...
# 119  PBI,PBI-PB      NYSE,NYSE  ...            PITNEY BOWES INC
# 120         XRX         Nasdaq  ...               201 MERRITT 7
# 121         MTW           NYSE  ...       11270 WEST PARK PLACE
# 122         STI         Nasdaq  ...             13355 NOEL ROAD
# 123         SLE         Nasdaq  ...  2912 COLORADO AVE, STE 203
#
#        business_street2  business_city  business_stateOrCountry  \
# 0                   NaN      CUPERTINO                       CA
# 1                   NaN        REDMOND                       WA
# 2                   NaN    SANTA CLARA                       CA
# 3                   NaN  MOUNTAIN VIEW                       CA
# 4                   NaN     MENLO PARK                       CA
# ..                  ...            ...                      ...
# 119  3001 SUMMER STREET       STAMFORD                       CT
# 120                 NaN        NORWALK                       CT
# 121         SUITE 10000      MILWAUKEE                       WI
# 122          SUITE 1100         DALLAS                       TX
# 123                 NaN   SANTA MONICA                       CA
#
#     business_zipCode  business_stateOrCountryDescription  \
# 0              95014                                  CA
# 1         98052-6399                                  WA
# 2              95051                                  CA
# 3              94043                                  CA
# 4              94025                                  CA
# ..               ...                                 ...
# 119       06926-0700                                  CT
# 120            06851                                  CT
# 121            53224                                  WI
# 122            75240                                  TX
# 123            90404                                  CA
#
#                                   naics stable 12 to 24  extended tickers  \
# 0                                334111            True        AAPL*,AAPL
# 1                         511210,334614            True              MSFT
# 2                                334413            True              NVDA
# 3                         518210,541511            True  GOOG,GOOGL,GOOG*
# 4                         518210,541511           False       FB*,FB,META
# ..                                  ...             ...               ...
# 119                339940,333318,334519           False        PBI,PBI-PB
# 120         334418,333316,334613,334118           False               XRX
# 121                333120,333923,336510           False               MTW
# 122  333618,333318,333992,335129,335999           False               STI
# 123                              541512           False               SLE
#
#      stable 14 to 24
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ..               ...
# 119            False
# 120            False
# 121            False
# 122            False
# 123            False
#
# [124 rows x 36 columns]

# %%
df_tech_sp500.to_csv("../../processed/tech_sp500_stable_extended_tickers.csv")
